# %% [markdown]
# Carmen Maranhas Gomez-Choco
#
# ## Descargamos el archivo en csv
# Al abrirlo en excel se observa una estructura organizada en una tabla con sus columnas identificadas correctamente.
# Tambien observamos como algunas celdas aparecen incompletas (no poseen todos los campos rellenos)
# importamos la libreria de pandas para poder realizar la practica

# %%
import pandas as pd

# %% [markdown]
# https://datos.gob.es/es/catalogo/a08002880-fiestas-de-interes-turistico-declaradas-en-castilla-la-mancha
# Este he cambiado el nombre la las columna sporque eran muy largas, las he cmabiado en la hoja excell

# %%
Turismo_data = pd.read_csv("Datos/FIESTAS.csv", sep = ";" )
Turismo_data
# Out:
#                            DENOMINACIÓN             LOCALIDAD    PROVINCIA  \
# 0             SEMANA SANTA Y TAMBORADA                AGRAMÓN     ALBACETE
# 1             FIESTA DE JUDAS Y MUÑECAS              ALAMILLO  CIUDAD REAL
# 2    CABALGATA AÉREA DE LOS REYES MAGOS              ALARILLA  GUADALAJARA
# 3                     FERIA DE ALBACETE              ALBACETE     ALBACETE
# 4                          SEMANA SANTA              ALBACETE     ALBACETE
# ..                                  ...                   ...          ...
# 144                 FIESTA DE LAS PACES  VILLARTA DE SAN JUAN  CIUDAD REAL
# 145              JORNADAS CALDERONIANAS                 YEPES       TOLEDO
# 146      FERIA DE TRADICIONES POPULARES                 YESTE     ALBACETE
# 147            ROMERÍA DE SAN BARTOLOMÉ                 YESTE     ALBACETE
# 148                     TORO ENMAROMADO                YUNCOS       TOLEDO
#
# ...

# %%
Turismo_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 10 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   DENOMINACIÓN                        149 non-null    object
#  1   LOCALIDAD                           149 non-null    object
#  2   PROVINCIA                           149 non-null    object
#  3   FECHA DE CELEBRACION DE LA FIESTA   149 non-null    object
#  4   FECHA_Resolucion                    149 non-null    object
#  5   FIESTAS_de_interes_turistico        12 non-null     object
#  6   FIESTAS_INTERES_REGIONAL            143 non-null    object
#  7   FECHA_BOE                           21 non-null     object
#  8   FECHA_ACTUALIZACION_BOE             6 non-null      object
#  9   OBSERVACIONES                       77 non-null     object
# dtypes: object(10)
# memory usage: 11.8+ KB

# %% [markdown]
# La info del DataFrame Turismo de Castilla la Mancha  nos indican que tiene 10 campos  con 149 registros o entradas
# Los datos fiesta de inters turistico (12) y fecha de actualizacion boe(6) tienen muy poca informacion

# %% [markdown]
# #https://datos.gob.es/es/catalogo/l01280796-alumbrado-navideno
# #El fichjeoo que descarga se llamade otra forma pero lo he renombrado porque creia que era ese el problema

# %%
alumbrado_data = pd.read_csv("Datos/ALUMBRADO.csv", sep = ";" )
alumbrado_data
# Out:
#                                               POSICION           MOTIVO  \
# 0                                             GRAN VIA  ARCOS COMPACTOS
# 1                                         PLAZA CHUECA  MOTIVO SINGULAR
# 2                                              MONTERA  ARCOS COMPACTOS
# 3             FUENCARRAL - DE GRAN VIA A HERNAN CORTES  ARCOS COMPACTOS
# 4               HORTALEZA. DE GRAN VIA A HERNAN CORTES  ARCOS COMPACTOS
# ..                                                 ...              ...
# 240                   ENTRADA PLAZA MAYOR POR C TOLEDO  MOTIVO NAVIDEÑO
# 241             PASEO DEL PRADO (DE CIBELES A NEPTUNO)        CADENETAS
# 242  PASEO DEL PRADO, ENTRE PLAZA DE NEPTUNO Y GLOR...        CADENETAS
# 243  PASEO DE RECOLETOS - CALZADA (DE CIBELES A COLON)        CADENETAS
# 244             PARQUE DEL RETIRO - PERIMETRO ESTANQUE          CEREZOS
#
#                                             COMENTARIO  idelem NOVEDAD  \
# ...

# %%
alumbrado_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 245 entries, 0 to 244
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   POSICION     245 non-null    object
#  1   MOTIVO       245 non-null    object
#  2   COMENTARIO   245 non-null    object
#  3   idelem       245 non-null    int64
#  4   NOVEDAD      245 non-null    object
#  5   DISEÑO       244 non-null    object
#  6   DISTRITOS    244 non-null    object
#  7   BARRIO       244 non-null    object
#  8   TIPO         245 non-null    object
#  9   LONGITUD     159 non-null    float64
#  10  N_ELEMENTOS  5 non-null      float64
#  11  PROMOTOR     245 non-null    object
#  12  TEXTO        245 non-null    object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 25.0+ KB

# %% [markdown]
# Alumnbrado Navideño tiene 13 campos y 245 registros. Escepto el campo n_elementos (5) y longitud (159) todos tienen la informacion completa

# %% [markdown]
# https://datos.gob.es/es/catalogo/ea0010587-gasto-medio-por-centro-segun-comunidad-autonoma-identificador-api-t25-p454-e01-a2022-2ccaa_9890-1car_9891-l0-0201011-px
# Este fichero no he modificado nada y es en el que me he dado cuenta que había que poner el separador

# %%
gasto_data = pd.read_csv("Datos/59739.csv", sep = ";" )
gasto_data
# Out:
#     Total Nacional Comunidades y Ciudades Autónomas  \
# 0   Total Nacional                              NaN
# 1   Total Nacional                     01 Andalucía
# 2   Total Nacional                        02 Aragón
# 3   Total Nacional       03 Asturias, Principado de
# 4   Total Nacional                04 Balears, Illes
# 5   Total Nacional                      05 Canarias
# 6   Total Nacional                     06 Cantabria
# 7   Total Nacional               07 Castilla y León
# 8   Total Nacional          08 Castilla - La Mancha
# 9   Total Nacional                      09 Cataluña
# 10  Total Nacional          10 Comunitat Valenciana
# 11  Total Nacional                   11 Extremadura
# 12  Total Nacional                       12 Galicia
# 13  Total Nacional          13 Madrid, Comunidad de
# 14  Total Nacional             14 Murcia, Región de
# 15  Total Nacional   15 Navarra, Comunidad Foral de
# 16  Total Nacional                    16 País Vasco
# ...

# %%
gasto_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 4 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Total Nacional                    20 non-null     object
#  1   Comunidades y Ciudades Autónomas  19 non-null     object
#  2   Gasto                             20 non-null     object
#  3   Total                             20 non-null     object
# dtypes: object(4)
# memory usage: 768.0+ bytes

# %% [markdown]
# El dataFrame gasto por comunidad autonoma tiene cuatro campos y estan todas las filas rellenas excepto comunidades autonomas que falta una

# %%
#rango de valores
gasto_data.index
# Out:
# RangeIndex(start=0, stop=20, step=1)

# %%
#nombre de las columnas
gasto_data.columns
# Out:
# Index(['Total Nacional', 'Comunidades y Ciudades Autónomas', 'Gasto', 'Total'], dtype='object')

# %%
gasto_data[["Total"]].max()
# Out:
# Total    777.764
# dtype: object

# %%
gasto_data[["Total"]].min()
# Out:
# Total    1.697.448
# dtype: object
