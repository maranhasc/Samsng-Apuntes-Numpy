# %% [markdown]
# Recursos para visualizacion
# https://matplotlib.org/
# https://seaborn.pydata.org/
# https://plotly.com/python/
# https://d3js.org/

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Matplotlib

# %%
#Grafico de barras básico de cuatro trimestres
x = ["C1","C2","C3","C4" ]
y = [350.5,562.3,253.4,695.0]
colores = ['blue', 'red', 'green', 'purple']
plt.bar(x, y,color=colores)
plt.title("Ventas por trimestre")
plt.xlabel('Trimestres')
plt.ylabel('Ventas en miles de €')
#plt.grid()
for i, valor in enumerate(y):
    plt.text(i, valor, str(valor), ha='center', va='bottom')

# %% [markdown]
# # Histograma

# %%
x = np.random.randn(1000)
#x = np.random.rand(1000)
plt.hist(x, bins=30, color = "red")
plt.title("Histograma")
plt.xlabel('Calificaciones')
# Out:
# Text(0.5, 0, 'Calificaciones')

# %%
estudiantes =pd.read_csv("Datos/data_studentlist.csv")
estudiantes
# Out:
#                 name gender  age  grade absence bloodtype  height  weight
# 0      Jared Diamond      M   23      3       Y         O   165.3    68.2
# 1     Sarah O'Donnel      F   22      2       N        AB   170.1    53.0
# 2       Brian Martin      M   24      4       N         B   175.0    80.1
# 3       David Hassel      M   23      3       N        AB   182.1    85.7
# 4    Clara Rodriquez      F   20      1       Y         A   168.0    49.5
# 5   Jennifer Lorentz      F   21      2       N         O   162.0    52.0
# 6        Susan Clark      F   22      1       N         O   155.2    45.3
# 7    Margareth Jones      F   23      1       N         A   176.9    55.0
# 8       John Bertsch      M   23      3       N         B   178.5    64.2
# 9     Jake Timmerman      M   22      2       N         B   176.1    61.3
# 10     Joshua Connor      M   24      4       Y         O   167.1    62.0
# 11      John Matsuda      M   22      2       N        AB   180.0    75.8
# ...

# %%
grupo_sanguineo = estudiantes["bloodtype"]
grupo_sanguineo
# Out:
# 0      O
# 1     AB
# 2      B
# 3     AB
# 4      A
# 5      O
# 6      O
# 7      A
# 8      B
# 9      B
# 10     O
# 11    AB
# 12     A
# 13     O
# 14     B
# 15     B
# 16     A
# Name: bloodtype, dtype: object

# %%
plt.hist(grupo_sanguineo)
plt.title("Histograma")
plt.xlabel('Grupo Sanguineo')
# Out:
# Text(0.5, 0, 'Grupo Sanguineo')

# %%
altura = estudiantes["height"]
altura
# Out:
# 0     165.3
# 1     170.1
# 2     175.0
# 3     182.1
# 4     168.0
# 5     162.0
# 6     155.2
# 7     176.9
# 8     178.5
# 9     176.1
# 10    167.1
# 11    180.0
# 12    162.2
# 13    176.1
# 14    158.2
# 15    168.6
# 16    169.2
# Name: height, dtype: float64

# %%
plt.hist(altura, orientation="horizontal")
plt.title("Estudiantes")
plt.xlabel('Altura')
# Out:
# Text(0.5, 0, 'Altura')

# %%
#grafico de estaturas separado por hombres y mujeres
altura_hombres = estudiantes[estudiantes['gender'] == 'M']['height']
altura_mujeres = estudiantes[estudiantes['gender'] == 'F']['height']

plt.hist([altura_hombres, altura_mujeres], bins=8, orientation="vertical", label=["Hombres", "Mujeres"])
plt.xlabel("Altura")
plt.title("Estudiantes")
plt.legend()

# %%
#histograma de alturas de hombres y mujeres

alturas_hombres = estudiantes[estudiantes['gender'] == 'M']['height']
alturas_mujeres = estudiantes[estudiantes['gender'] == 'F']['height']

plt.hist(alturas_hombres, bins=10, color='blue', label='M')
plt.hist(alturas_mujeres, bins=10, alpha=0.6, color='pink', label='F')

plt.xlabel('Altura')
plt.ylabel('Frecuencia')
plt.legend()
plt.title('Histograma de Alturas de Hombres y Mujeres')
plt.show()

# %% [markdown]
# ### Boxplot

# %%
altura = estudiantes["height"].sort_values()
altura
# Out:
# 6     155.2
# 14    158.2
# 5     162.0
# 12    162.2
# 0     165.3
# 10    167.1
# 4     168.0
# 15    168.6
# 16    169.2
# 1     170.1
# 2     175.0
# 9     176.1
# 13    176.1
# 7     176.9
# 8     178.5
# 11    180.0
# 3     182.1
# Name: height, dtype: float64

# %%
plt.boxplot(estudiantes["height"])
#linea amarilla es la mediana
#la caja va desde el primer cuartil al tercero, la mediana es la mitad
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2b81f947b50>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2b81f97c0d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2b81f9478b0>],
#  'medians': [<matplotlib.lines.Line2D at 0x2b81f97c610>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2b81f97c8b0>],
#  'means': []}

# %%
#('Boxplot de Alturas de Hombres y Mujeres')
alturas_hombres = estudiantes[estudiantes['gender'] == 'M']['height']
alturas_mujeres = estudiantes[estudiantes['gender'] == 'F']['height']

plt.title('Boxplot de Alturas de Hombres y Mujeres')
#plt.boxplot([estudiantes["height"], estudiantes["weight"]], labels=["Altura", "Peso"])
plt.boxplot([alturas_hombres, alturas_mujeres], labels=["Hombres", "Mujeres"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2b8248d01f0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2b8248d0610>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2b8248a7f10>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x2b8248d0b50>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x2b8248d0df0>,
# ...
#  'means': []}

# %% [markdown]
# ### Diagramas Scatter/line plot

# %%
x = np.linspace(0,10,100)
y = np.sin(x)

# %%
plt.plot(x,y, linewidth=5, linestyle=":", color="green")
#plt.plot(x,y, linewidth=5)
plt.xlabel("x")
plt.ylabel("Sin(x)")
#plt.xlim([0,5]) # limites para x 
#plt.ylim([-0.5,0.5]) # limites para y
# Out:
# Text(0, 0.5, 'Sin(x)')

# %% [markdown]
# ## Seaborn

# %%
car_data = sns.load_dataset("mpg") #mpg: milles per gallon
car_data
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
car_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
sns.displot(car_data["mpg"], bins=20, kde=True)

# %%
sns.displot(car_data["acceleration"], bins=20, kde=True)

# %%
sns.scatterplot(x="weight", y="mpg", data=car_data)
# a mayor peso menos distancia
# Out:
# <Axes: xlabel='weight', ylabel='mpg'>

# %%
#añade un histograma de peso y millasXgalon
sns.jointplot(x="weight", y="mpg", data=car_data, kind="reg")#  kind= "hex", "scatter", "reg"
# a mayor peso menos distancia 
#kind="reg" regresion, la linea intenta dibujar la tendencia

# %%
#añade un histograma de peso y millasXgalon
sns.jointplot(x="weight", y="mpg", data=car_data, kind="hex")#  kind= "hex", "scatter", "reg"
# a mayor peso menos distancia 
#kind="reg" regresion, la linea intenta dibujar la tendencia

# %%
#todo estoson variables de scatterplot
sns.lmplot(x= "weight", y= 'mpg', data = car_data, hue= 'origin')

# %%
sns.lmplot(data=car_data, x="weight", y="mpg", hue="origin", col="origin")

# %%
sns.barplot(x="origin", y="mpg",data=car_data, estimator=np.mean)
# Out:
# <Axes: xlabel='origin', ylabel='mpg'>

# %%
sns.barplot(x="origin", y="mpg",data=car_data, hue="origin", estimator=np.max)    
#, hue="origin", col="origin"
# Out:
# <Axes: xlabel='origin', ylabel='mpg'>

# %%
sns.barplot(x="origin", y="mpg",data=car_data, hue="origin", estimator=np.min)    
#, hue="origin", col="origin"b
# Out:
# <Axes: xlabel='origin', ylabel='mpg'>

# %%
sns.countplot(x="origin",data=car_data, hue = "cylinders")    
#, hue="origin", col="origin"b
# Out:
# <Axes: xlabel='origin', ylabel='count'>

# %%
sns.boxplot(data=car_data,y="mpg")
# Out:
# <Axes: ylabel='mpg'>

# %%
sns.boxplot(x="mpg", y="origin", data=car_data)
# Out:
# <Axes: xlabel='mpg', ylabel='origin'>

# %%
sns.boxplot(data= car_data, x='origin', y= 'mpg', hue= 'cylinders')
# los rombos son datos anormalmnete buenos, son datos sueltos
# Out:
# <Axes: xlabel='origin', ylabel='mpg'>

# %%
sns.violinplot(data= car_data, x="origin", y= "mpg")
# Out:
# <Axes: xlabel='origin', ylabel='mpg'>

# %%
#borramos las columnas que no son numericas porque la correlacion relaciona columnas numericas
numeric_data = car_data.drop(columns=["origin", "name"])
numeric_data
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year
# 0            70
# 1            70
# 2            70
# 3            70
# 4            70
# ..          ...
# ...

# %%
#coeficiente de correlacion, lo calcula con .corr()
correlation_data = numeric_data.corr()
correlation_data
# Out:
#                    mpg  cylinders  displacement  horsepower    weight  \
# mpg           1.000000  -0.775396     -0.804203   -0.778427 -0.831741
# cylinders    -0.775396   1.000000      0.950721    0.842983  0.896017
# displacement -0.804203   0.950721      1.000000    0.897257  0.932824
# horsepower   -0.778427   0.842983      0.897257    1.000000  0.864538
# weight       -0.831741   0.896017      0.932824    0.864538  1.000000
# acceleration  0.420289  -0.505419     -0.543684   -0.689196 -0.417457
# model_year    0.579267  -0.348746     -0.370164   -0.416361 -0.306564
#
#               acceleration  model_year
# mpg               0.420289    0.579267
# cylinders        -0.505419   -0.348746
# displacement     -0.543684   -0.370164
# horsepower       -0.689196   -0.416361
# weight           -0.417457   -0.306564
# acceleration      1.000000    0.288137
# model_year        0.288137    1.000000

# %% [markdown]
# ## ¿Qué es la correlación?
#
# La correlación es una medida estadística que indica el grado de relación entre dos variables. En concreto, la correlación lineal sirve para determinar cuánto de correlacionadas linealmente están dos variables distintas.
#
#
# Dos variables están relacionadas cuando al variar los valores de una variable también cambian los valores de la otra variable. Por ejemplo, si al aumentar la variable A también aumenta la variable B, existe una correlación entre las variables A y B.

# %%
#mapas de calor
sns.heatmap(correlation_data, annot=True)
# Out:
# <Axes: >

# %%
# Crear un DataFrame de ejemplo
data = {'A': [1, 2, 3],
        'B': [4, 5, 6],
        'C': [7, 8, 9]}

df = pd.DataFrame(data)

# Crear un mapa de calor con Seaborn a partir del DataFrame
sns.heatmap(df, annot=True, cmap='coolwarm')

# Mostrar el mapa de calor
plt.show()

# %%
# Importar librerias
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Crear dataframe con Iris
iris_data = sns.load_dataset("iris")
iris_data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# Consultar info del dataframe
iris_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# ## 1. Escribe el código Python con Seaborn que muestre el scatter plot con Pandas visto en clase.

# %%
# El visto en clase
diccionario_colores = {"setosa": "red", "virginica":"green", "versicolor":"blue"}
colores = iris_data["species"].apply(lambda x: diccionario_colores[x])
iris_data.plot.scatter(x="petal_length", y="petal_width", c=colores)

# Mostrar
plt.show()

# %%
# Solucion
sns.scatterplot(data=iris_data, x="petal_length", y="petal_width", hue="species", palette=diccionario_colores)
plt.show()

# %% [markdown]
# ## 2. Propón un gráfico que consideres interesante aplicado a los datos de las flores del iris y comenta el resultado.

# %%
# Representación propuesta
sns.lmplot(data=iris_data, x="sepal_width", y="petal_width", hue="species", palette=diccionario_colores)

# Mostrar
plt.show()

# %%
#propon un grafico que consideres interesante aplicado a los datos de las flores de iris y comenta el resultado
#dice que no tiene sentido porq en el eje x si aparecen los datos pero en el eje y no tiene sentido
sns.heatmap(iris_data.groupby(['species']).corr())
plt.show()

# %%
diccionario_colores = {"setosa": "red", "virginica": "green", "versicolor": "blue"}

sns.pairplot(iris_data, hue="Species", palette=diccionario_colores)
plt.show()
#generaliza la grafica primera pero con muchas combinaciones, en la diagonal pone las graficas

# %%
# Probando con pairplot
sns.pairplot(iris_data, hue="Species", markers=["o", "s", "D"])
#igual que el anterior pero cambiando los marcadores
plt.show()

# %%
#aqui lo que se ve es que entre la altura del sepalo y la altura del sepalo es 0?, cuanto mas altyo el sepalo mas corto el petalo
#cuanto mas ancho mas corto tambien
#
sns.heatmap(iris_data.corr(numeric_only=True))
plt.show()

# %%
numeric_iris_data = iris_data.drop(columns=["species"])
numeric_iris_data
correlation_data = numeric_iris_data.corr()
correlation_data
sns.heatmap(correlation_data, annot=True)
plt.show()

# %%
g=sns.PairGrid(iris_data)
#g.map_diag(sns.displot,color="blue") displot esta deprecated
g.map_diag(sns.histplot,color="blue")
g.map_upper(sns.regplot,color="black")
g.map_lower(sns.scatterplot,color="green")
plt.show()

# %%
correlation_data = correlation_data.corr(numeric_only=True)
correlation_data
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.941906      0.976054     0.963754
# sepal_width      -0.941906     1.000000     -0.992151    -0.994843
# petal_length      0.976054    -0.992151      1.000000     0.998029
# petal_width       0.963754    -0.994843      0.998029     1.000000

# %%
sns.heatmap(correlation_data)
plt.show()

# %%
##Analisis datos de salud
#REPASO PANDAS

# %%
import pandas as pd
import seaborn as sns

# %%
datos_salud = pd.read_csv("Datos/healthcare_dataset.csv", sep = ",", header='infer')
datos_salud
# Out:
#                       Name  Age  Gender Blood Type Medical Condition  \
# 0          Tiffany Ramirez   81  Female         O-          Diabetes
# 1              Ruben Burns   35    Male         O+            Asthma
# 2                Chad Byrd   61    Male         B-           Obesity
# 3        Antonio Frederick   49    Male         B-            Asthma
# 4      Mrs. Brandy Flowers   51    Male         O-         Arthritis
# ...                    ...  ...     ...        ...               ...
# 9995            James Hood   83    Male         A+           Obesity
# 9996       Stephanie Evans   47  Female        AB+         Arthritis
# 9997  Christopher Martinez   54    Male         B-         Arthritis
# 9998           Amanda Duke   84    Male         A+         Arthritis
# 9999             Eric King   20    Male         B-         Arthritis
#
#      Date of Admission             Doctor                   Hospital  \
# ...

# %%
datos_salud.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                10000 non-null  object
#  1   Age                 10000 non-null  int64
#  2   Gender              10000 non-null  object
#  3   Blood Type          10000 non-null  object
#  4   Medical Condition   10000 non-null  object
#  5   Date of Admission   10000 non-null  object
#  6   Doctor              10000 non-null  object
#  7   Hospital            10000 non-null  object
#  8   Insurance Provider  10000 non-null  object
#  9   Billing Amount      10000 non-null  float64
#  10  Room Number         10000 non-null  int64
#  11  Admission Type      10000 non-null  object
#  12  Discharge Date      10000 non-null  object
#  13  Medication          10000 non-null  object
#  14  Test Results        10000 non-null  object
# ...

# %%
#Escribe una instruccion Pandas sobre los datos de salud

# %%
datos_salud.columns
# Out:
# Index(['Name', 'Age', 'Gender', 'Blood Type', 'Medical Condition',
#        'Date of Admission', 'Doctor', 'Hospital', 'Insurance Provider',
#        'Billing Amount', 'Room Number', 'Admission Type', 'Discharge Date',
#        'Medication', 'Test Results'],
#       dtype='object')

# %%
maximo_edad = datos_salud[["Age"]].max()
maximo_edad
# Out:
# Age    85
# dtype: int64

# %%
genero = datos_salud["Gender"].value_counts()
genero
# Out:
# Female    5075
# Male      4925
# Name: Gender, dtype: int64

# %%
Pacientes_con_Diabetes = datos_salud[datos_salud["Medical Condition"] == "Diabetes"]
print("Hay : ", len(Pacientes_con_Diabetes), " pacientes con Diabetes")
Pacientes_con_Diabetes
# Out:
# Hay :  1623  pacientes con Diabetes
#                     Name  Age  Gender Blood Type Medical Condition  \
# 0        Tiffany Ramirez   81  Female         O-          Diabetes
# 8             Ryan Hayes   33    Male         A+          Diabetes
# 12    Christina Williams   85  Female         A+          Diabetes
# 13          William Page   72  Female         A+          Diabetes
# 16       Olivia Gonzalez   64    Male        AB-          Diabetes
# ...                  ...  ...     ...        ...               ...
# 9961       Joseph Wilson   78  Female         A+          Diabetes
# 9962            Jenny Ho   48    Male        AB-          Diabetes
# 9971      Gregory Torres   56  Female         A+          Diabetes
# 9984      Erica Crawford   72    Male        AB+          Diabetes
# 9994        Jorge Obrien   69    Male         A+          Diabetes
#
#      Date of Admission            Doctor                    Hospital  \
# ...

# %%
datos_salud[3:8]
# Out:
#                   Name  Age  Gender Blood Type Medical Condition  \
# 3    Antonio Frederick   49    Male         B-            Asthma
# 4  Mrs. Brandy Flowers   51    Male         O-         Arthritis
# 5       Patrick Parker   41    Male        AB+         Arthritis
# 6       Charles Horton   82    Male        AB+      Hypertension
# 7         Patty Norman   55  Female         O-         Arthritis
#
#   Date of Admission           Doctor                   Hospital  \
# 3        2020-05-02   Brian Chandler                 Garcia Ltd
# 4        2021-07-09   Dustin Griffin    Jones, Brown and Murray
# 5        2020-08-20      Robin Green                   Boyd PLC
# 6        2021-03-22  Patricia Bishop  Wheeler, Bryant and Johns
# 7        2019-05-16    Brian Kennedy                  Brown Inc
#
#   Insurance Provider  Billing Amount  Room Number Admission Type  \
# 3           Medicare    23303.322092          480         Urgent
# ...

# %%
#Media de edad
int(datos_salud["Age"].mean())
# Out:
# 51

# %%
datos_salud["Medical Condition"].unique()
# Out:
# array(['Diabetes', 'Asthma', 'Obesity', 'Arthritis', 'Hypertension',
#        'Cancer'], dtype=object)

# %%
#Agrupaciones por tipo de sangre
datos_salud.groupby("Blood Type").size()
# Out:
# Blood Type
# A+     1241
# A-     1238
# AB+    1258
# AB-    1275
# B+     1244
# B-     1252
# O+     1248
# O-     1244
# dtype: int64

# %%
datos_salud.loc[datos_salud["Age"] > 80]
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 0        Tiffany Ramirez   81  Female         O-          Diabetes
# 6         Charles Horton   82    Male        AB+      Hypertension
# 12    Christina Williams   85  Female         A+          Diabetes
# 31        Rodney Maynard   81    Male        AB-           Obesity
# 35    Jennifer Rodriguez   83  Female        AB-            Asthma
# ...                  ...  ...     ...        ...               ...
# 9976       Colton Weaver   81  Female        AB-         Arthritis
# 9977       James Calhoun   84    Male         O+            Cancer
# 9987        Bobby Pierce   84  Female         O-           Obesity
# 9995          James Hood   83    Male         A+           Obesity
# 9998         Amanda Duke   84    Male         A+         Arthritis
#
#      Date of Admission            Doctor                    Hospital  \
# 0           2022-11-17    Patrick Parker            Wallace-Hamilton
# ...

# %%
# Total de facturación (Billing Amount) por proveedor de seguros (Insurance Provider).
datos_salud.groupby('Insurance Provider')['Billing Amount'].sum()
# Out:
# Insurance Provider
# Aetna               5.232179e+07
# Blue Cross          5.212586e+07
# Cigna               5.234017e+07
# Medicare            4.812977e+07
# UnitedHealthcare    5.025047e+07
# Name: Billing Amount, dtype: float64

# %%
#Hospital más visitado

frecuencia_hospital = datos_salud['Hospital'].value_counts()
hospital_mas_visitado = frecuencia_hospital.idxmax()

hospital_mas_visitado
# Out:
# 'Smith PLC'

# %%
# doctor con mas pacientes
doctor = datos_salud['Doctor'].value_counts().idxmax()
print("Médico con más pacientes:", doctor)
# Out:
# Médico con más pacientes: Michael Johnson

# %%
#cuantos hay agrupados por genero y enfermedad
medical_genero = datos_salud.groupby(['Gender', 'Medical Condition'])['Name'].count()
medical_genero
# Out:
# Gender  Medical Condition
# Female  Arthritis            815
#         Asthma               874
#         Cancer               887
#         Diabetes             825
#         Hypertension         836
#         Obesity              838
# Male    Arthritis            835
#         Asthma               834
#         Cancer               816
#         Diabetes             798
#         Hypertension         852
#         Obesity              790
# Name: Name, dtype: int64

# %%
#Mujeres con tipo de sangre A+

mujeres_A_positivo = len(datos_salud[(datos_salud['Gender'] == 'Female') & (datos_salud['Blood Type'] == 'A+')])

print("El número de mujeres con sangre A+ es: ", mujeres_A_positivo)
# Out:
# El número de mujeres con sangre A+ es:  629

# %%
datos_salud.groupby(['Age'])[['Medication']].value_counts().sort_values(ascending= False)
# Out:
# Age  Medication
# 78   Penicillin     49
# 20   Ibuprofen      47
# 21   Lipitor        45
# 56   Penicillin     43
# 72   Lipitor        43
#                     ..
# 84   Paracetamol    18
# 67   Ibuprofen      17
# 47   Aspirin        17
# 62   Paracetamol    17
# 69   Paracetamol    15
# Length: 340, dtype: int64

# %%
# Vamos a quedarnos con la edad y la condición médica
health_data_columns = ["Age", "Medical Condition"]
health_data_sample = datos_salud[health_data_columns]
health_data_sample

# Ordenar la muestra por edad de mayor a menor
health_data_sorted = health_data_sample.sort_values(by="Age", ascending=False)
health_data_sorted

# Ver cuál es la enfermedad más común por edades
med_condition_by_age = health_data_sorted.groupby('Age')['Medical Condition'].agg(lambda x: x.value_counts().idxmax())
print(med_condition_by_age)
# Out:
# Age
# 18    Hypertension
# 19          Asthma
# 20        Diabetes
# 21          Cancer
# 22       Arthritis
#           ...
# 81        Diabetes
# 82        Diabetes
# 83       Arthritis
# 84          Asthma
# 85        Diabetes
# Name: Medical Condition, Length: 68, dtype: object

# %%
edad_30 = datos_salud[datos_salud["Age"] == 30]
edadmenos_40 =  datos_salud[datos_salud["Age"] < 40]
edad_rango = datos_salud[(datos_salud['Age'] > 50) & (datos_salud['Age'] <= 60)]
edad_rango
# Out:
#                       Name  Age  Gender Blood Type Medical Condition  \
# 4      Mrs. Brandy Flowers   51    Male         O-         Arthritis
# 7             Patty Norman   55  Female         O-         Arthritis
# 20         William Johnson   55  Female        AB+         Arthritis
# 22                Haley Li   51    Male         B-           Obesity
# 24          Beverly Miller   54    Male         A-            Asthma
# ...                    ...  ...     ...        ...               ...
# 9971        Gregory Torres   56  Female         A+          Diabetes
# 9981    Catherine Carrillo   54    Male         B-         Arthritis
# 9988         Julie Johnson   60  Female         A-            Cancer
# 9991           John Holder   56  Female         A+            Asthma
# 9997  Christopher Martinez   54    Male         B-         Arthritis
#
#      Date of Admission            Doctor                 Hospital  \
# 4           2021-07-09    Dustin Griffin  Jones, Brown and Murray
# ...
